# %%
#resultado = 4+5*2
#resultado = 5+3*8/2-1
#resultado = 6/2+5*3/2*3
#resultado = 12*3-(5*4/2+8)*2

resultado = 4+5*2
print(f"1ra operacion: {resultado}")
resultado = 5+3*8/2-1 
print(f"2da operacion: {resultado}")
resultado = 6/2+5*3/2*3
print(f"3ra operacion: {resultado}")
resultado = 12*3-(5*4/2+8)*2
print(f"4ta operacion: {resultado}")
# Out:
# 1ra operacion: 14
# 2da operacion: 16.0
# 3ra operacion: 25.5
# 4ta operacion: 0.0

# %%
#aritmetic problem

result = 15/3*(7+(68-15*33+(45**2/5)/3)/2)+19
print(result)
result = ((1240%6*2**4)>(7+8*3**4))>((15*2)) == (30*2/4)
print(result)
# Out:
# -676.0
# False

# %%
import math

#variables
peso = 90
altura = 1.80

a,b,c,d = 2,3,4,5
l1,l2,l3 = 2,3,4

#imc 
imc = peso/altura**2
if imc >= 18.50 and imc <=25.00:
    condicion = "normal"
elif imc > 25.00:
    condicion = "obeso/a"
else:
    condicion = "delgado/a"
print(f"su imc es: {round(imc,2)} usted está:", condicion)

#2
resultado = a+(a+((a+b/c+d)/a+(a/b)))
print(resultado)

#3
result = l1+l2+l3/2
print(result)

#4
a,c = 1,1.5
variable = (-b+ math.sqrt(b**2 -4*a*c))/(2*a)
print(f"formula del estudiante: {variable}")
# Out:
# su imc es: 27.78 usted está: obeso/a
# 8.541666666666668
# 7.0
# formula del estudiante: -0.6339745962155614
